# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/retail_transactions_sample.csv')

# %%
df
# Out:
#      transaction_id        date region  season     category sub_category  \
# 0                 1  2023-04-13  North  Spring         Home      Kitchen
# 1                 2  2024-03-11  North    Fall         Home        Decor
# 2                 3  2025-05-10   East  Summer         Home        Decor
# 3                 4  2023-09-28   West  Winter         Home      Kitchen
# 4                 5  2023-04-17  North  Summer  Electronics  Accessories
# ..              ...         ...    ...     ...          ...          ...
# 995             996  2023-01-10  North    Fall     Clothing          Men
# 996             997  2025-04-03  North  Summer     Clothing          Men
# 997             998  2025-03-08  South  Summer     Clothing          Men
# 998             999  2023-08-30   East  Winter     Clothing         Kids
# 999            1000  2023-09-08   West  Winter  Electronics  Accessories
#
#      cost_price  sale_price  inventory_days
# 0        219.48      304.53              10
# ...

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['profit_margin'] = ((df['sale_price'] - df['cost_price']) / df['sale_price']) * 100

# %%
df['profit_margin']
# Out:
# 0      27.928283
# 1      22.436775
# 2      22.600966
# 3      14.900592
# 4      12.864135
#          ...
# 995    26.656103
# 996    31.779957
# 997    29.534651
# 998    23.244544
# 999    26.042174
# Name: profit_margin, Length: 1000, dtype: float64

# %%
df
# Out:
#      transaction_id        date region  season     category sub_category  \
# 0                 1  2023-04-13  North  Spring         Home      Kitchen
# 1                 2  2024-03-11  North    Fall         Home        Decor
# 2                 3  2025-05-10   East  Summer         Home        Decor
# 3                 4  2023-09-28   West  Winter         Home      Kitchen
# 4                 5  2023-04-17  North  Summer  Electronics  Accessories
# ..              ...         ...    ...     ...          ...          ...
# 995             996  2023-01-10  North    Fall     Clothing          Men
# 996             997  2025-04-03  North  Summer     Clothing          Men
# 997             998  2025-03-08  South  Summer     Clothing          Men
# 998             999  2023-08-30   East  Winter     Clothing         Kids
# 999            1000  2023-09-08   West  Winter  Electronics  Accessories
#
#      cost_price  sale_price  inventory_days  profit_margin
# ...

# %%
corr = df[['inventory_days','profit_margin']].corr()
corr
# Out:
#                 inventory_days  profit_margin
# inventory_days        1.000000      -0.024068
# profit_margin        -0.024068       1.000000

# %%
sns.scatterplot(data=df, x='inventory_days', y='profit_margin', hue='category')
plt.title("Inventory Days vs Profitability")
plt.show()
